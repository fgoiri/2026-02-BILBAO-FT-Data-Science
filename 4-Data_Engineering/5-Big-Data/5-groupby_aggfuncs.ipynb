# %% [markdown]
# ### Pyspark GroupBy And Aggregate Functions

# %% [markdown]
# #### INICIAMOS LA SESIÓN

# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName('dataframe').getOrCreate()
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# 26/05/25 12:05:06 WARN Utils: Your hostname, MacBook-Pro-de-Fatima.local, resolves to a loopback address: 127.0.0.1; using 10.20.52.205 instead (on interface en0)
# 26/05/25 12:05:06 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/05/25 12:05:07 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://10.20.52.205:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v4.1.2</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>dataframe</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# #### GROUPBY Y AGGREGATE

# %%
df_pyspark = spark.read.csv('data/test3.csv', header=True, inferSchema=True)
df_pyspark.show()
# Out:
# +---------+------------+------+
# |     Name| Departments|salary|
# +---------+------------+------+
# |    Krish|Data Science| 10000|
# |    Krish|         IOT|  5000|
# |   Mahesh|    Big Data|  4000|
# |    Krish|    Big Data|  4000|
# |   Mahesh|Data Science|  3000|
# |Sudhanshu|Data Science| 20000|
# |Sudhanshu|         IOT| 10000|
# |Sudhanshu|    Big Data|  5000|
# |    Sunny|Data Science| 10000|
# |    Sunny|    Big Data|  2000|
# +---------+------------+------+

# %%
df_pyspark.printSchema()
# Out:
# root
#  |-- Name: string (nullable = true)
#  |-- Departments: string (nullable = true)
#  |-- salary: integer (nullable = true)

# %% [markdown]
# GROUPBY

# %%
# Por nombre y suma de salarios de cada persona

df_pyspark.groupBy('Name').sum().show()

#si tuviera más de una columna numérica: df.groupBy("Name").agg(sum(col("Salary")).alias("TotalSalary"))
# Out:
# +---------+-----------+
# |     Name|sum(salary)|
# +---------+-----------+
# |Sudhanshu|      35000|
# |    Sunny|      12000|
# |    Krish|      19000|
# |   Mahesh|       7000|
# +---------+-----------+

# %%
df_pyspark.groupBy('Name').max().show()
# Out:
# +---------+-----------+
# |     Name|max(salary)|
# +---------+-----------+
# |Sudhanshu|      20000|
# |    Sunny|      10000|
# |    Krish|      10000|
# |   Mahesh|       4000|
# +---------+-----------+

# %%
df_pyspark.groupBy('Name').min().show()
# Out:
# +---------+-----------+
# |     Name|min(salary)|
# +---------+-----------+
# |Sudhanshu|       5000|
# |    Sunny|       2000|
# |    Krish|       4000|
# |   Mahesh|       3000|
# +---------+-----------+

# %%
# Por departamentos y suma de salarios

df_pyspark.groupBy('Departments').sum().show()
# Out:
# +------------+-----------+
# | Departments|sum(salary)|
# +------------+-----------+
# |         IOT|      15000|
# |    Big Data|      15000|
# |Data Science|      43000|
# +------------+-----------+

# %%
# Por departamento y salario medio

df_pyspark.groupBy('Departments').mean().show()
# Out:
# +------------+-----------+
# | Departments|avg(salary)|
# +------------+-----------+
# |         IOT|     7500.0|
# |    Big Data|     3750.0|
# |Data Science|    10750.0|
# +------------+-----------+

# %%
# Para contar el número de empleados por departamento

df_pyspark.groupBy('Departments').count().show()
# Out:
# +------------+-----+
# | Departments|count|
# +------------+-----+
# |         IOT|    2|
# |    Big Data|    4|
# |Data Science|    4|
# +------------+-----+

# %% [markdown]
# AGGREGATE

# %%
df_pyspark.groupBy('Departments').agg({'name':'count','Salary':'sum'}).show()
# Out:
# +------------+-----------+-----------+
# | Departments|sum(Salary)|count(name)|
# +------------+-----------+-----------+
# |         IOT|      15000|          2|
# |    Big Data|      15000|          4|
# |Data Science|      43000|          4|
# +------------+-----------+-----------+
# 26/05/25 17:39:36 WARN HeartbeatReceiver: Removing executor driver with no recent heartbeats: 439780 ms exceeds timeout 120000 ms
# 26/05/25 17:39:36 WARN SparkContext: Killing executors is not supported by current scheduler.
# 26/05/25 17:39:43 ERROR Inbox: Ignoring error
# org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.SparkThreadUtils$.awaitResult(SparkThreadUtils.scala:53)
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:359)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRefByURI(RpcEnv.scala:102)
# ...
