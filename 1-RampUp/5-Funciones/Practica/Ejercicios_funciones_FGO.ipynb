# %% [markdown]
# ![imagen](./img/ejercicios.png)

# %% [markdown]
# # Ejercicios funciones
# ## Ejercicio 1
# Escribe una función que convierta números del 1 al 7 en nombres de los dias de la semana. La función constará de un único argumento numérico y una salida de tipo string

# %%
def semana(x):
        if x == 1:
            return "Lunes"
        elif x == 2:
            return "Martes"
        elif x == 3:
            return "Miércoles"
        elif x == 4:
            return "Jueves"
        elif x == 5:
            return "Viernes"
        elif x == 6:
            return "Sábado"
        elif x == 7:
            return "Domingo"
        else:
            print("Error, número no admitido, escribe de nuevo")
            
semana(2)
# Out:
# 'Martes'

# %% [markdown]
# ## Ejercicio 2
# En el ejercicio 8 de flujos de control, creábamos una pirámide invertida de números desde el 5. Crea una función que replique el comportamiento de la pirámide, y utiliza un único parámetro de entrada de la función para determinar el número de filas de la pirámide.

# %%
def piramide(n):

    for i in range(n, 0, -1):
        for j in range(i, 0, -1):
            print(j, end=" ")
        print()
        
piramide(5)
# Out:
# 5 4 3 2 1
# 4 3 2 1
# 3 2 1
# 2 1
# 1

# %% [markdown]
# ## Ejercicio 3
# Escribe una función que compare dos números. La función tiene dos argumentos y hay tres salidas posibles: que sean iguales, que el primero sea  mayor que el segundo, o que el segundo sea mayor que el primero

# %%
def funcion(x,y):
    if x == y:
        print("Los números son iguales")
    elif x > y:
        print("El primer número introducido es mayor que el segundo")
    else:
        print("El primer número introducido es menor que el segundo")
        
funcion(1,2)
# Out:
# El primer número introducido es menor que el segundo

# %% [markdown]
# ## Ejercicio 4
# Escribe una función que sea un contador de letras. En el primer argumento tienes que introducir un texto, y el segundo que sea una letra que contar. La función tiene que devolver un entero con el número de veces que aparece esa letra, tanto mayúscula, como minúscula

# %%
def contador_letras(texto,letra):
    contador = 0
    
    for caracter in texto:
        if caracter.lower() == letra.lower():
            contador = contador + 1

    return contador

contador_letras("Ornitorrinco","o")
# Out:
# 3

# %% [markdown]
# ## Ejercicio 5
# Escribe una función que tenga un único argumento, un string. La salida de la función tiene que ser un diccionario con el conteo de todas las letras de ese string, siendo la clave la letra y el valor el conteo.

# %%
def contador_dict(texto):
    diccionario = {}
    texto = texto.lower()

    for letra in texto:

        if letra in diccionario:
            diccionario[letra] = diccionario[letra] + 1
        else:
            diccionario[letra] = 1

    return diccionario

contador_dict("Ornitorrinco")
# Out:
# {'o': 3, 'r': 3, 'n': 2, 'i': 2, 't': 1, 'c': 1}

# %% [markdown]
# ## Ejercicio 6
# Escribir una función que añada o elimine elementos en una lista. La función necesita los siguientes argumentos:
# * lista: la lista donde se añadirán o eliminarán los elementos
# * comando: "add" o "remove"
# * elemento: Por defecto es None.
#
# Tendrá como salida la lista

# %%
def cambios_lista(lista, comando, elemento = None):
    
    if comando == "add":
        if elemento is not None:
            lista.append(elemento)
    elif comando == "remove":
        if elemento in lista:
            lista.remove(elemento)
    return lista

cambios_lista([1,2,3],"add",4)
# Out:
# [1, 2, 3, 4]

# %% [markdown]
# ## Ejercicio 7
# Crea una función que reciba un número arbitrario de palabras, y devuelva una frase completa, separando las palabras con espacios.

# %%
def frase(palabras):
    for palabras in 
    
    return palabras.append()

# %% [markdown]
# ## Ejercicio 8
# Escribe un programa que obtenga el enésimo número de la [serie de Fibonacci](https://es.wikipedia.org/wiki/Sucesi%C3%B3n_de_Fibonacci). Tienes que crear una función recursiva con un único argumento.
#
# ```Python
# fibonacci(2) = 1
# fibonacci(4) = 3
# fibonacci(5) = 5
# fibonacci(8) = 21
# ```

# %% [markdown]
# fibonacci(n) = fibonacci(n-1) + fibonacci(n-2)

# %% [markdown]
# ## Ejercicio 9
# Define en una única celda las siguientes funciones:
# * Función que calcule el área de un cuadrado
# * Función que calcule el área de un triángulo
# * Función que calcule el área de un círculo
#
# En otra celda, calcular el area de:
# * Dos círculos de radio 10 + un triángulo de base 3 y altura 7
# * Un cuadrado de lado = 10 + 3 círculos (uno de radio = 4 y los otros dos de radio = 6) + 5 triángulos de base = 2 + altura = 4

# %%
def areas

# %% [markdown]
# ## Ejercicio 10
#
# Guarda las funciones de estos ejercicios en un fichero llamado `funciones.py` e importalas desde este jupyter notebook para probar que puedes hacer uso de ellas.
