# %% [markdown]
# ![imagen](./img/ejercicios.png)

# %% [markdown]
# # Ejercicios Flujos de control

# %% [markdown]
# ## Ejercicio 1
# Declara una variable numérica que será una hora cualquiera del día. Implementa la siguiente casuística:
#
# * Si es entre las 0 y las 8, print "Durmiendo"
# * Si es entre las 9 y las 18, print "Trabajando"
# * Si es entre las 19 y las 21, print "Clase"
# * Si es entre las 22 y las 24, print "Descanso"
# * En cualquier otro caso, print "Transporte o error"

# %%
hora = 0

if hora < 0 or hora > 24:
    print("Transporte o error")
elif hora >= 0 or hora < 8:
    print("Durmiendo")
elif hora > 9 or hora < 18:
    print("Trabajando")
elif hora > 19 or hora < 21:
    print("Clase")
elif hora > 22 or hora < 24:
    print("Descanso")
# Out:
# Durmiendo

# %% [markdown]
# ## Ejercicio 2
# En este ejercicio vamos a implementar un calculador de precios de casas muy sencillo. Tenemos las siguientes variables:
#
# > superficie
# >
# > distrito
#
# Implementa la siguiente casuística:
#
# 1. Si el distrito es "Moncloa" o "Centro", y además la superficie es superior a 100 metros cuadrados, el precio de la casa es de 1000
# 2. Si el distrito es "Salamanca", y además la superficie de la casa es al menos de 150 metros, el precio de la casa es de 1500
# 3. Si el distrito no es "Retiro" y la superficie está entre 60 y 80 metros, el precio es de 600
# 4. En cualquier otro caso, el precio será de 0

# %%
distrito = "Moncloa"
superficie = 75

if (distrito == "Moncloa" or distrito == "Centro") and (superficie >= 100):
    precio = 1000
elif distrito == "Salamanca" and (superficie >= 150):
    precio = 1500
elif distrito != "Retiro" and (60 <= superficie <= 80):
    precio = 600
else: 
    precio = 0
print("El precio de la casa en el distrito de",distrito,"y con una superficie de",superficie,"m2 es de:",precio)
# Out:
# El precio de la casa en el distrito de Moncloa y con una superficie de 75 m2 es de: 600

# %% [markdown]
# ## Ejercicio 3
# En este ejercicio vamos a realizar un programa muy parecido. Para este caso queremos que se cumplan las siguientes condiciones:
#
# 1. Primero se compruebe si el distrito es "Retiro". Si es asá, que imprima "Distrito Retiro", y si no, "Otro distrito"
# 2. Si el distrito es "Retiro", comprueba si la superficie es mayor de 100 metros cuadrados. En tal caso, que imprima un precio de 1000, y si no, de 500.
#
# Prueba a usar `ifs` anidados

# %%
distrito = "Retiro"
superficie = 120
if distrito == "Retiro":
    print("El distrito es Retiro")
    if superficie >= 100:
        precio = 1000
        print("El precio de una casa de más de 100 m2 en el Retiro es de", precio, "lereles")
    else:
        precio = 500
        print("El precio de una casa de menos de 100 m2 en el Retiro es de", precio, "lereles")
else: 
    print("El distrito no es Retiro, es",distrito)
# Out:
# El distrito es Retiro
# El precio de una casa de más de 100 m2 en el Retiro es de 1000 lereles

# %% [markdown]
# ## Ejercicio 4
# Escribe un programa que tenga dos variables: un numero, y una lista numérica. El programa debe recorrer la lista e imprimir por pantalla cada elemento de la lista multiplicado por el número

# %%
numero = 2
lista = [1, 2, 3, 4]
for i in lista:
    mult = i * numero
    print("El resultado de la multiplicación de", i ,"por", numero,"es de", mult)
# Out:
# El resultado de la multiplicación de 1 por 2 es de 2
# El resultado de la multiplicación de 2 por 2 es de 4
# El resultado de la multiplicación de 3 por 2 es de 6
# El resultado de la multiplicación de 4 por 2 es de 8

# %% [markdown]
# ## Ejercicio 5
# Imprime por pantalla cada número del -10 al -1. En ese orden. Consulta [la documentación](https://www.w3schools.com/python/ref_func_range.asp) de `range`

# %%
list(range(-10, -1))
# Out:
# [-10, -9, -8, -7, -6, -5, -4, -3, -2]

# %% [markdown]
# ## Ejercicio 6
# Dada la siguiente lista:
#
# > list1 = [12, 15, 32, 42, 55, 75, 122, 132, 150, 180, 200]
#
# Implementa un programa que los recorra e imprima por pantalla todos los divisibles por 5. Si nos encontramos con alguno que sea mayor que 150, detener el bucle.

# %%
list1 = [12, 15, 32, 42, 55, 75, 122, 132, 150, 180, 200]
for i, valor in enumerate(list1):
    if (valor % 5 == 0) and valor <= 150:
        print("Los elementos divisibles por 5 en la lista y menores de 150 son: ",valor)
    elif valor > 150:
        break
# Out:
# Los elementos divisibles por 5 en la lista y menores de 150 son:  15
# Los elementos divisibles por 5 en la lista y menores de 150 son:  55
# Los elementos divisibles por 5 en la lista y menores de 150 son:  75
# Los elementos divisibles por 5 en la lista y menores de 150 son:  150

# %% [markdown]
# ## Ejercicio 7
# Escribe un programa en Python que imprima por pantalla todos los números que cumplan que sean divisibles por 5 y divisibles por 7, dentro del rango de valores (150, 350).

# %%
print("Los números del rango (150, 350) divisibles por 5 y 7 son:")
for i in range(150, 350):
    if (i % 5 == 0) and (i % 7 == 0):
        print(i)
# Out:
# Los números del rango (150, 350) divisibles por 5 y 7 son:
# 175
# 210
# 245
# 280
# 315

# %% [markdown]
# ## Ejercicio 8
# Implementa un programa que imprima por pantalla el siguiente patrón
#
# 5 4 3 2 1
#
# 4 3 2 1
#
# 3 2 1
#
# 2 1
#
# 1
#
# NOTA: NO hay lineas en blanco entre una línea y otra.

# %%
for i in (range(5,0,-1)):
    for j in (range(i,0,-1)):
        print(j, end = " ")
    print()
# Out:
# 5 4 3 2 1
# 4 3 2 1
# 3 2 1
# 2 1
# 1

# %% [markdown]
# ## Ejercicio 9
# En este ejercicio vamos a crear un pequeño juego. Se trata de intentar adivinar un numero del 1 al 5. Tenemos dos intentos para acertar. Pasos a seguir:
#
# 1. Ya viene implementado con la librería `random` cómo obtener un número aleatorio del 1 al 5
# 2. Tendrás que declarar en una variable el numero de vidas, y mediante un bucle while, comprobar que todavia quedan vidas.
# 3. Dentro del bucle, obtener el valor del usuario y comprobar si es ese el numero a adivinar. Si no, actualizar las vidas.
# 4. Si acertamos, salimos del bucle e imprimimos por pantalla "You win". Y si perdemos también salimos del bucle, pero en este caso imprimimos por pantalla "You lose".
#
# TIP: te puede resultar útil usar la sentencia `else` cuando acabe el bucle `while`. Lo que haya dentro de ese `else` se ejecutará una vez acabe la ejecución del `while`. Lo podrás usar para cuando pierdas.

# %%
# Out:
# 2

# %%
import random
num_alea = random.randint(1,5)
print(num_alea)
num_vidas = 2
while num_vidas > 0:
    intento = int(input("Adivina el número del 1 al 5"))
    if intento == num_alea:
        print("You win")
        break
    else:
        num_vidas = num_vidas - 1
else: 
    print("You lose")
# Out:
# You win
