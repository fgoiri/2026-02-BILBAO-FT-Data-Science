# %% [markdown]
# ## Juego del Ahorcado
# El funcionamiento es que vaya mostrando por pantalla ```_ _ _ _ _``` las rayas bajas correspondientes al número de letras que tiene la palabra a adivinar. El usuario deberá insertar una letra y, si esa letra existe, se mostrará o mostrarán las letras acertadas ```S _ S _ _```.
#
# Si falla, se mostrará el número de errores que lleva y, si lleva 6 errores, entonces se mostrará "Fin del juego".
# Encapsúlalo en una función.

# %%
def juego_ahorcado():
    palabra = "ornitorrinco"
    letras_correctas = []
    vidas = 6
    
    
    print("Vamos a jugar al juego del AHORCADO")
    print("_ " * len(palabra))
    
    while vidas > 0:
        
        estado = ""
        
        for letra in palabra:
            
            if letra in letras_correctas:
                estado += letra + " "
                
            else:
                estado += "_ "
                print(f"Incorrecto. Vidas restantes: {vidas}")
        
        intento = input("Introduce una letra: ").lower()
        
        if intento in palabra:
            
            letras_correctas.append(intento)
            
        else:
            vidas -= 1
            print(f"Incorrecto. Vidas restantes: {vidas}")
            
    print("Fin del juego")
        
juego_ahorcado()
# Out:
# Vamos a jugar al juego del AHORCADO
# _ _ _ _ _ _ _ _ _ _ _ _

# %%
# Se puede importar la librería random para que no siempre te salga la misma palabra
import random
import time # hemos importado time porque ayuda a los prints de los aciertos y errores
# Se puede crear como Irene una lista con palabras y luego con la librería random que escoja una de ellas al azar
lista_palabras = ["ornitorrinco", "cocodrilo", "manzana",""]
palabra_elegida = random.choice(lista_palabras)

# poner la palabra en mayúsculas:
palabra_elegida = palabra_elegida.upper()

# printar las rayas de debajo de la palabra elegida, se hace un len de la palabra elegida.
palabra_oculta = "_" * len(palabra_elegida)
palabra_oculta = list(palabra_oculta)
print(*palabra_oculta)

# Número de "vidas", o errores que tenemos
vidas = 6

# entonces aquí empezaría el programa con el while vidas > 0...

def ahorcado():
    while vidas > 0:
        time.sleep(1)     # aqui conseguimos 
        letra_usuario = input("Introduce una letra: ") # Le pedimos al usuario la primera letra
        letra_usuario = letra_usuario.upper() # La letra la pasamos a minuscula si la ha introducido con mayuscula
        
        if                  # aquí ya empezamos con el verdadero código detrás del juego.
# Out:
# _ _ _ _ _ _ _ _ _ _ _ _
