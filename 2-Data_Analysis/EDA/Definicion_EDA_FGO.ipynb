# %% [markdown]
# ![imagen](./img/ejercicios.png)

# %% [markdown]
# # INFORMACIÓN DEL PROYECTO

# %% [markdown]
# ### TÍTULO

# %%
#Escribe el título del proyecto en Markdown
titulo = "Factores que influyen en la valoración de libros en Goodreads"

# %% [markdown]
# ### TEMA

# %%
# Describe brevemente el tema del proyecto en Markdown
tema = "Este proyecto analiza la relación entre los hábitos de lectura y el bienestar percibido de los usuarios, utilizando datos del dataset de Goodreads."

"Dado que no se dispone de variables clínicas directas sobre salud mental, se emplean métricas como las valoraciones de libros, la popularidad y "
"las características de los mismos como aproximaciones indirectas al grado de satisfacción o engagement de los lectores."

"El objetivo es identificar patrones en los hábitos de lectura que puedan asociarse con experiencias más positivas."

# %% [markdown]
# ### HIPÓTESIS

# %% [markdown]
# Define aquí lo que será la hipótesis de tu proyecto.
# Deberás tener más de una, pero tu proyecto lo harás teniendo una principal hipótesis.

# %%
# Escribe tu hipótesis principal en Markdown
hipotesis_1 = "El número de páginas de un libro influye en su valoración media."

hipotesis_2 = "Los libros más populares (con mayor número de valoraciones) tienden a tener valoraciones medias más altas."

hipotesis_3 = "Los autores más populares presentan valoraciones medias superiores a autores menos conocidos."

hipotesis_4  ="Epoca del año en la que se publica el libro influye en su valoración media."

# %%
# Escribe más hipótesis si las hubiera en Markdown
# hipotesis_2 = ""
# hipotesis_3 = ""
# hipotesis_4 = ""
# hipotesis_5 = ""
# ...

# %% [markdown]
# ## OBTENCIÓN DE LOS DATOS

# %% [markdown]
# ### DATASETS Y FUENTES ALTERNATIVAS DE DATOS

# %% [markdown]
# Incluye aquí una vista del dataset o datasets de los que partirás para poder evaluar tu hipótesis. <br>
# También incluye el origen de estos datos y su fuente.

# %%
import pandas as pd
# guarda en variables los datasets y su fuente
df_1 = pd.DataFrame()
fuente_1 = "https://www.kaggle.com/datasets/jealousleopard/goodreadsbooks/data"
df_2 = pd.DataFrame()
fuente_2 = "https://www.kaggle.com/datasets/bahramjannesarr/goodreads-book-datasets-10m?"
# df_3 = pd.DataFrame()
# fuente_3 = ""
# df_4 = pd.DataFrame()
# fuente_4 = ""
# df_5 = pd.DataFrame()
# fuente_5 = ""
# ...

# %% [markdown]
# Muestra mediante un head() los principales datasets con los que vas a trabajar

# %%
# Primer dataset
# df_1.head()

# %%
# Siguiente dataset...
# df_2.head()
