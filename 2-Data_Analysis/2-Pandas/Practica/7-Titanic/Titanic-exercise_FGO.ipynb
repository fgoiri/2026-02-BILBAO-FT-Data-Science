# %% [markdown]
#    #                                                  Titanic Exercise
#
#    ![titanic](https://userscontent2.emaze.com/images/a5f68f37-6349-4065-a1fc-921cbe7401b2/958230111417e36d6b3c67ffd7bc3494.jpeg)
#    #### Practise Pandas

# %% [markdown]
# First of all, import the needed libraries.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# 1. Read in filename and call the variable `titanic`
#     - Explore the `titanic` dataset using `info`, `dtypes` & `describe`

# %%
titanic = pd.read_csv('data/titanic.csv')
titanic.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   str
#  3   sex        1309 non-null   str
#  4   age        1046 non-null   float64
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   str
#  8   fare       1308 non-null   float64
#  9   cabin      295 non-null    str
#  10  embarked   1307 non-null   str
#  11  boat       486 non-null    str
#  12  body       121 non-null    float64
#  13  home.dest  745 non-null    str
# dtypes: float64(3), int64(4), str(7)
# memory usage: 143.3 KB

# %%
titanic.dtypes
# Out:
# pclass         int64
# survived       int64
# name             str
# sex              str
# age          float64
# sibsp          int64
# parch          int64
# ticket           str
# fare         float64
# cabin            str
# embarked         str
# boat             str
# body         float64
# home.dest        str
# dtype: object

# %%
titanic.describe()
# Out:
#             pclass     survived          age        sibsp        parch  \
# count  1309.000000  1309.000000  1046.000000  1309.000000  1309.000000
# mean      2.294882     0.381971    29.881138     0.498854     0.385027
# std       0.837836     0.486055    14.413493     1.041658     0.865560
# min       1.000000     0.000000     0.170000     0.000000     0.000000
# 25%       2.000000     0.000000    21.000000     0.000000     0.000000
# 50%       3.000000     0.000000    28.000000     0.000000     0.000000
# 75%       3.000000     1.000000    39.000000     1.000000     0.000000
# max       3.000000     1.000000    80.000000     8.000000     9.000000
#
#               fare        body
# count  1308.000000  121.000000
# mean     33.295479  160.809917
# std      51.758668   97.696922
# min       0.000000    1.000000
# 25%       7.895800   72.000000
# 50%      14.454200  155.000000
# 75%      31.275000  256.000000
# max     512.329200  328.000000

# %% [markdown]
# 2. Create a separate dataframe with the columns `['name', 'sex', 'age']`, call it `people`
#
# It can be done two ways, do it both!

# %%
# La manera que yo haría:
people = titanic[["name", "sex", "age"]]
people.head(10)
# Out:
#                                               name     sex    age
# 0                    Allen, Miss. Elisabeth Walton  female  29.00
# 1                   Allison, Master. Hudson Trevor    male   0.92
# 2                     Allison, Miss. Helen Loraine  female   2.00
# 3             Allison, Mr. Hudson Joshua Creighton    male  30.00
# 4  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.00
# 5                              Anderson, Mr. Harry    male  48.00
# 6                Andrews, Miss. Kornelia Theodosia  female  63.00
# 7                           Andrews, Mr. Thomas Jr    male  39.00
# 8    Appleton, Mrs. Edward Dale (Charlotte Lamson)  female  53.00
# 9                          Artagaveytia, Mr. Ramon    male  71.00

# %%
# Otra manera:
people_1 = titanic.loc[:, ['name', 'sex', 'age']]
people_1.head(10)
# Out:
#                                               name     sex    age
# 0                    Allen, Miss. Elisabeth Walton  female  29.00
# 1                   Allison, Master. Hudson Trevor    male   0.92
# 2                     Allison, Miss. Helen Loraine  female   2.00
# 3             Allison, Mr. Hudson Joshua Creighton    male  30.00
# 4  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.00
# 5                              Anderson, Mr. Harry    male  48.00
# 6                Andrews, Miss. Kornelia Theodosia  female  63.00
# 7                           Andrews, Mr. Thomas Jr    male  39.00
# 8    Appleton, Mrs. Edward Dale (Charlotte Lamson)  female  53.00
# 9                          Artagaveytia, Mr. Ramon    male  71.00

# %% [markdown]
# 3. Print the output of `people` showing the first three rows and the last four rows, using `append`,`tail` and `head`

# %%
# Con append, tail y head no se puede hacer a la vez por la versión de pandas según claude.ia así que he hecho un concat:
resultado = pd.concat([people.head(3), people.tail(4)])
resultado
# Out:
#                                 name     sex    age
# 0      Allen, Miss. Elisabeth Walton  female  29.00
# 1     Allison, Master. Hudson Trevor    male   0.92
# 2       Allison, Miss. Helen Loraine  female   2.00
# 1305           Zabour, Miss. Thamine  female    NaN
# 1306       Zakarian, Mr. Mapriededer    male  26.50
# 1307             Zakarian, Mr. Ortin    male  27.00
# 1308              Zimmerman, Mr. Leo    male  29.00

# %% [markdown]
# 4. Slice the row from 3 to 9, call it `s_titanic`

# %%
s_titanic = titanic.iloc[2:9]
s_titanic
# Out:
#    pclass  survived                                             name     sex  \
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# 5       1         1                              Anderson, Mr. Harry    male
# 6       1         1                Andrews, Miss. Kornelia Theodosia  female
# 7       1         0                           Andrews, Mr. Thomas Jr    male
# 8       1         1    Appleton, Mrs. Edward Dale (Charlotte Lamson)  female
#
#     age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 2   2.0      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 5  48.0      0      0   19952   26.5500      E12        S    3    NaN
# ...

# %% [markdown]
# 5. Slice the row from 40 to 63 in reverse order, call it `s_titanic_rev`

# %%
s_titanic_rev = titanic[63:39:-1] # -1 para hacer el reverse
s_titanic_rev
# Out:
#     pclass  survived                                               name  \
# 63       1         1  Chaffee, Mrs. Herbert Fuller (Carrie Constance...
# 62       1         0                        Chaffee, Mr. Herbert Fuller
# 61       1         1  Cavendish, Mrs. Tyrell William (Julia Florence...
# 60       1         0                      Cavendish, Mr. Tyrell William
# 59       1         1  Cassebeer, Mrs. Henry Arthur Jr (Eleanor Genev...
# 58       1         0                             Case, Mr. Howard Brown
# 57       1         1          Carter, Mrs. William Ernest (Lucile Polk)
# 56       1         1                         Carter, Mr. William Ernest
# 55       1         1                          Carter, Miss. Lucile Polk
# 54       1         1                Carter, Master. William Thornton II
# 53       1         0                             Carrau, Mr. Jose Pedro
# 52       1         0                            Carrau, Mr. Francisco M
# ...

# %% [markdown]
# 6. Slice the columns from the starting column to `'parch'`, call it `left_columns`

# %%
left_columns = titanic.loc[:,:'parch']
left_columns
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex    age  sibsp  parch
# 0     female  29.00      0      0
# ...

# %% [markdown]
# 7. Slice the columns from `'name'` to `'age'`, call it `middle_columns`

# %%
middle_columns = titanic.loc[:,'name':'age']
middle_columns
# Out:
#                                                  name     sex    age
# 0                       Allen, Miss. Elisabeth Walton  female  29.00
# 1                      Allison, Master. Hudson Trevor    male   0.92
# 2                        Allison, Miss. Helen Loraine  female   2.00
# 3                Allison, Mr. Hudson Joshua Creighton    male  30.00
# 4     Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.00
# ...                                               ...     ...    ...
# 1304                             Zabour, Miss. Hileni  female  14.50
# 1305                            Zabour, Miss. Thamine  female    NaN
# 1306                        Zakarian, Mr. Mapriededer    male  26.50
# 1307                              Zakarian, Mr. Ortin    male  27.00
# 1308                               Zimmerman, Mr. Leo    male  29.00
#
# [1309 rows x 3 columns]

# %% [markdown]
# 8. Slice the columns from `'ticket'` to the end, call it `right_columns`

# %%
right_columns = titanic.loc[:,'ticket':]
right_columns
# Out:
#       ticket      fare    cabin embarked boat   body  \
# 0      24160  211.3375       B5        S    2    NaN
# 1     113781  151.5500  C22 C26        S   11    NaN
# 2     113781  151.5500  C22 C26        S  NaN    NaN
# 3     113781  151.5500  C22 C26        S  NaN  135.0
# 4     113781  151.5500  C22 C26        S  NaN    NaN
# ...      ...       ...      ...      ...  ...    ...
# 1304    2665   14.4542      NaN        C  NaN  328.0
# 1305    2665   14.4542      NaN        C  NaN    NaN
# 1306    2656    7.2250      NaN        C  NaN  304.0
# 1307    2670    7.2250      NaN        C  NaN    NaN
# 1308  315082    7.8750      NaN        S  NaN    NaN
#
#                             home.dest
# 0                        St Louis, MO
# 1     Montreal, PQ / Chesterville, ON
# 2     Montreal, PQ / Chesterville, ON
# 3     Montreal, PQ / Chesterville, ON
# 4     Montreal, PQ / Chesterville, ON
# ...                               ...
# 1304                              NaN
# ...

# %% [markdown]
# 9. What is the name of the oldest person who died in the Titanic? Was he or she travelling alone or had any family travelling with them?

# %% [markdown]
# In order to give an answer to the second question you should find out which columns give you that info. Usually part of your job as a Data Scientist will be get to know the dataset which you are working with. In this case the columns which give you that info are the following:
#         - 'sibsp' Number of Siblings/Spouses Aboard
#         - 'parch' Number of Parents/Children Aboard

# %%
eldest = titanic[titanic['survived'] == 0]['age'].max()

señor_random = titanic[(titanic['survived'] == 0) & (titanic['age'] == eldest)][['name', 'age', 'sibsp', 'parch']]
señor_random
# The eldest person aboard the Titanic and died was 74 years old y viajaba sólo y sin familia.
# Out:
#                      name   age  sibsp  parch
# 1235  Svensson, Mr. Johan  74.0      0      0

# %% [markdown]
# 10. Create the list of 5 random numbers of rows from 0 to the lenght of the dataframe, call it `rows`
#
# ex. `rows = [3,7,99,52,48]` use `random` library

# %% [markdown]
# This list of numbers are random, could be different.

# %%
import random

# %%
rows = [random.randint(0, len(titanic)-1) for _ in range(5)]
rows
# Out:
# [368, 1166, 767, 334, 47]

# %%
rows_irene = random.sample(range(len(titanic)), 5)
rows_irene
# Out:
# [512, 652, 747, 101, 10]

# %% [markdown]
# 11. Create the list of three column labels, call it `cols`

# %%
cols = ["label1", "label2", "label3"]
cols
# Out:
# ['label1', 'label2', 'label3']

# %% [markdown]
# 12. Use both lists `rows` and `cols` to create a new dataframe

# %%
df_12 = pd.DataFrame(columns = cols, index = rows)
df_12
# Out:
#      label1 label2 label3
# 368     NaN    NaN    NaN
# 1166    NaN    NaN    NaN
# 767     NaN    NaN    NaN
# 334     NaN    NaN    NaN
# 47      NaN    NaN    NaN

# %% [markdown]
# 13. Create a boolean array with the condition of being a woman or a man, using the `sex` column, where **female** is True. Call it `array_fe`

# %%
array_fe = np.array(titanic['sex'] == 'female')
array_fe
# Out:
# array([ True, False,  True, ..., False, False, False], shape=(1309,))

# %% [markdown]
# 14. Rename the column `"sex"` to `"gender"` and filter the `titanic` dataframe with the boolean array, call it `woman_titanic`

# %%
woman_titanic = titanic.rename(columns = {'sex':'gender'})[array_fe]
woman_titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 2          1         0                     Allison, Miss. Helen Loraine
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 6          1         1                Andrews, Miss. Kornelia Theodosia
# 8          1         1    Appleton, Mrs. Edward Dale (Charlotte Lamson)
# ...      ...       ...                                              ...
# 1286       3         1  Whabee, Mrs. George Joseph (Shawneene Abi-Saab)
# 1290       3         1                 Wilkes, Mrs. James (Ellen Needs)
# 1300       3         1          Yasbeck, Mrs. Antoni (Selini Alexander)
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
#
#       gender   age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %% [markdown]
# 15. How many woman were younger than 18? Call the variable `minor_wo`

# %%
minor_wo = woman_titanic[woman_titanic['age'] < 18]
print(f"Mujeres menores de 18: {len(minor_wo)}")
# Out:
# Mujeres menores de 18: 72

# %%
# Dataframe de las mujeres menores de 18 que embarcaron en el Titanic:
minor_wo
# Out:
#       pclass  survived                                       name  gender  \
# 2          1         0               Allison, Miss. Helen Loraine  female
# 55         1         1                  Carter, Miss. Lucile Polk  female
# 92         1         1  Dick, Mrs. Albert Adrian (Vera Gillespie)  female
# 159        1         1               Hippach, Miss. Jean Gertrude  female
# 187        1         1                  Lines, Miss. Mary Conover  female
# ...      ...       ...                                        ...     ...
# 1257       3         1                 Touma, Miss. Maria Youssef  female
# 1265       3         0                  Van Impe, Miss. Catharina  female
# 1279       3         0       Vestrom, Miss. Hulda Amanda Adolfina  female
# 1300       3         1    Yasbeck, Mrs. Antoni (Selini Alexander)  female
# 1304       3         0                       Zabour, Miss. Hileni  female
#
#        age  sibsp  parch    ticket      fare    cabin embarked boat   body  \
# ...

# %% [markdown]
# 16. How many woman that were less than 18 actually died? Call the variable `dead_wo`

# %%
dead_wo = minor_wo[minor_wo['survived'] == 0]
print(f"De las mujeres menores de 18 murieron {len(dead_wo)}")
# Out:
# De las mujeres menores de 18 murieron 22

# %%
# Dataframe de las mujeres menos de 18 que murieron en el Titanic:
dead_wo
# Out:
#       pclass  survived                                  name  gender   age  \
# 2          1         0          Allison, Miss. Helen Loraine  female   2.0
# 623        3         0    Andersson, Miss. Ebba Iris Alfrida  female   6.0
# 624        3         0     Andersson, Miss. Ellis Anna Maria  female   2.0
# 627        3         0  Andersson, Miss. Ingeborg Constanzia  female   9.0
# 628        3         0     Andersson, Miss. Sigrid Elisabeth  female  11.0
# 650        3         0                 Attalah, Miss. Malake  female  17.0
# 679        3         0               Boulos, Miss. Nourelain  female   9.0
# 807        3         0      Ford, Miss. Robina Maggie "Ruby"  female   9.0
# 828        3         0           Goodwin, Miss. Jessie Allis  female  10.0
# 829        3         0            Goodwin, Miss. Lillian Amy  female  16.0
# 841        3         0                  Hagardon, Miss. Kate  female  17.0
# ...

# %% [markdown]
# 17. Drop rows with *Nan* in `titanic` with `how='any'` and print the shape

# %%
titanic.dropna(axis = 0, how = "any").shape
# Me he quedado sin ninguna columna...menos mal que solo es visualizarlo...
# Out:
# (0, 14)

# %% [markdown]
# 18. Drop rows with *Nan* in `titanic` with `how='all'` and print the shape

# %%
titanic.dropna(axis = 0, how = 'all').shape # Elimina todas las filas que tienen TODO valores nulos.
# Out:
# (1309, 14)

# %% [markdown]
# Check in [here](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.dropna.html) why the shapes are different.

# %% [markdown]
# 19. Drop columns in `titanic` with more than 1000 missing values and print the columns remaining

# %%
cols_19 = titanic.columns[titanic.isna().sum() <= 1000] # primero guardamos el calculo de los NaNs por columna
titanic_19 = titanic[cols_19]
titanic_19.columns.tolist()
# Out:
# ['pclass',
#  'survived',
#  'name',
#  'sex',
#  'age',
#  'sibsp',
#  'parch',
#  'ticket',
#  'fare',
#  'embarked',
#  'boat',
#  'home.dest']

# %%
# Por lo visto esto es mejor...
titanic_19b = titanic.dropna(axis=1, thresh=len(titanic) - 1000)
titanic_19b.columns.tolist()
# Out:
# ['pclass',
#  'survived',
#  'name',
#  'sex',
#  'age',
#  'sibsp',
#  'parch',
#  'ticket',
#  'fare',
#  'embarked',
#  'boat',
#  'home.dest']

# %% [markdown]
# 20. Calculate the ratio of missing values at the `boat` column.

# %%
(titanic.isna().sum() / (len(titanic)) * 100)['boat']
# El ratio de valores missing en la columna boat es de 62.87 y es una mierda de sacar
# Out:
# np.float64(62.87242169595111)

# %% [markdown]
# 21.  Group `titanic` by `'pclass'` and aggregate by the columns `age` & `fare`, by `max` and `median` and assign it to `by_class`

# %%
by_class = titanic.groupby('pclass')[['age','fare']].agg(['max','median'])
by_class
# Out:
#          age             fare
#          max median       max   median
# pclass
# 1       80.0   39.0  512.3292  60.0000
# 2       70.0   29.0   73.5000  15.0458
# 3       74.0   24.0   69.5500   8.0500

# %% [markdown]
# 22. Print the maximum age in each class from `by_class`

# %%
by_class['age']['max']
# Out:
# pclass
# 1    80.0
# 2    70.0
# 3    74.0
# Name: max, dtype: float64

# %% [markdown]
# 23. Print the median fare in each class from `by_class`

# %%
by_class['fare']['median']
# Out:
# pclass
# 1    60.0000
# 2    15.0458
# 3     8.0500
# Name: median, dtype: float64

# %% [markdown]
# 24. Using [`.pivot_table()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.pivot_table.html) to count how many women or men survived by class, call it `counted`.
#
# Don't panic and read the documentation!

# %%
counted = titanic.pivot_table(index='pclass', columns='sex', values='survived', aggfunc='sum')
counted
# Out:
# sex     female  male
# pclass
# 1          139    61
# 2           94    25
# 3          106    75

# %%
counted_bis = titanic.pivot_table(index='sex', columns='pclass', values='survived', aggfunc='sum') # si pones margins = True entonces te saca la suma de las filas y de las columnas
counted_bis
# Out:
# pclass    1   2    3
# sex
# female  139  94  106
# male     61  25   75

# %% [markdown]
# 25. Add a new column with the sum of survived men and women, call it `counted['total']`

# %%
counted_bis['total'] = counted_bis.sum(axis=1) # suma filas
counted_bis
# Out:
# pclass    1   2    3  total
# sex
# female  139  94  106    339
# male     61  25   75    161

# %%
counted['total'] = counted.sum(axis=1) # suma filas
counted
# Out:
# sex     female  male  total
# pclass
# 1          139    61    200
# 2           94    25    119
# 3          106    75    181

# %% [markdown]
# 26. Sort `counted` by the `'total'` column. In which class the people survived the most?

# %%
counted.sort_values('total', ascending = False)
# Sobrevivieron más en la primera clase, qué sorpresa!!
# Out:
# sex     female  male  total
# pclass
# 1          139    61    200
# 3          106    75    181
# 2           94    25    119

# %% [markdown]
# 27. Please, show only the rows using a mask with the following conditions:
#     - They are woman
#     - From third class
#     - Younger than 30
#     - They survived
#
#     ¿How many rows fulfill the condition?

# %%
mask_27 = (titanic['sex'] == 'female') & (titanic['pclass'] == 3) & (titanic['age'] < 30) & (titanic['survived'] == 1)
len(titanic[mask_27])
# Hay 57 filas
# Out:
# 57

# %% [markdown]
# 28. Now, show only the rows using `.loc` with the following conditions:
#     - They are man
#     - From first class
#     - Older than 50
#     - They died
#
#     ¿How many rows fulfill the condition?

# %%
len(titanic.loc[(titanic['sex'] == 'male') & (titanic['pclass'] == 1) & (titanic['age'] > 50) & (titanic['survived'] == 0)])
# Hay 29 filas en esta condición
# Out:
# 29

# %% [markdown]
# 29. Print the uniques values at the column `'name'`

# %%
titanic['name'].nunique # Los valores únicos
# Out:
# <bound method IndexOpsMixin.nunique of 0                         Allen, Miss. Elisabeth Walton
# 1                        Allison, Master. Hudson Trevor
# 2                          Allison, Miss. Helen Loraine
# 3                  Allison, Mr. Hudson Joshua Creighton
# 4       Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
#                              ...
# 1304                               Zabour, Miss. Hileni
# 1305                              Zabour, Miss. Thamine
# 1306                          Zakarian, Mr. Mapriededer
# 1307                                Zakarian, Mr. Ortin
# 1308                                 Zimmerman, Mr. Leo
# Name: name, Length: 1309, dtype: str>

# %%
titanic['name'].unique() # vemos los valores unicos de la columna, este sería el resultado del ejercicio.
# Out:
# <StringArray>
# [                  'Allen, Miss. Elisabeth Walton',
#                   'Allison, Master. Hudson Trevor',
#                     'Allison, Miss. Helen Loraine',
#             'Allison, Mr. Hudson Joshua Creighton',
#  'Allison, Mrs. Hudson J C (Bessie Waldo Daniels)',
#                              'Anderson, Mr. Harry',
#                'Andrews, Miss. Kornelia Theodosia',
#                           'Andrews, Mr. Thomas Jr',
#    'Appleton, Mrs. Edward Dale (Charlotte Lamson)',
#                          'Artagaveytia, Mr. Ramon',
#  ...
#                              'Yasbeck, Mr. Antoni',
#          'Yasbeck, Mrs. Antoni (Selini Alexander)',
#                             'Youseff, Mr. Gerious',
#                                'Yousif, Mr. Wazli',
#                            'Yousseff, Mr. Gerious',
#                             'Zabour, Miss. Hileni',
#                            'Zabour, Miss. Thamine',
#                        'Zakarian, Mr. Mapriededer',
# ...

# %% [markdown]
# 30. Find if was there any `name` repeated at the Titanic?
#
# Hint: There were two people with the same name, who?

# %%
titanic['name'].value_counts()[titanic['name'].value_counts() > 1]
# Los nombres repetidos son: Ms. Kate Connolly y Mr. James Kelly
# Out:
# name
# Connolly, Miss. Kate    2
# Kelly, Mr. James        2
# Name: count, dtype: int64

# %%
titanic[titanic["name"].duplicated(keep=False)]
# Out:
#      pclass  survived                  name     sex   age  sibsp  parch  \
# 725       3         1  Connolly, Miss. Kate  female  22.0      0      0
# 726       3         0  Connolly, Miss. Kate  female  30.0      0      0
# 924       3         0      Kelly, Mr. James    male  34.5      0      0
# 925       3         0      Kelly, Mr. James    male  44.0      0      0
#
#      ticket    fare cabin embarked boat  body home.dest
# 725  370373  7.7500   NaN        Q   13   NaN   Ireland
# 726  330972  7.6292   NaN        Q  NaN   NaN   Ireland
# 924  330911  7.8292   NaN        Q  NaN  70.0       NaN
# 925  363592  8.0500   NaN        S  NaN   NaN       NaN

# %% [markdown]
# 31. Using `matplotlib` find the appropriate visualization to show the distribution of the column `'age'`

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(titanic['age'], bins=30, edgecolor = "black")
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Age distribution');

# Para mi un histograma es el mejor gráfico para mostrar la distribución de la columna age.

# %% [markdown]
# 32. Using `matplotlib` find the appropriate plot to visualize the column `'gender'`

# %%
titanic['sex'].value_counts().plot(kind='bar', edgecolor = "black")

plt.xlabel('Gender')
plt.ylabel('Count')
plt.title('Gender distribution');

# Para poder visualizar la columna de género, lo mejor es hacer un conteo de los hombres y mujeres y luego hacer un histograma
# Iban a bordo del Titanic más homberes que mujeres, casi el doble parece.

# %% [markdown]
# 32b. What if you also plot the column `'gender'` using the function [`countplot`](https://seaborn.pydata.org/generated/seaborn.countplot.html) from the library [`seaborn`](https://seaborn.pydata.org/)?
#
# Remember you have never used `seaborn` before, therefore you should install it before importing it.

# %%
import seaborn as sns

# %%
sns.countplot(x='sex', data=titanic)

plt.title('Count of passengers by gender');

# Más sencillo aún, donde solo le decimos un countplot y por la columna sexo, y te da el histograma igual.

# %% [markdown]
# 33. Using the function [`catplot`](https://seaborn.pydata.org/generated/seaborn.catplot.html) from the library `seaborn`, find out if the hypothesis _"Women are more likely to survive shipwrecks"_ is true or not.
#
# You should get something like this:

# %% [markdown]
# ![catplot](./img/catplotgen.png)

# %%
sns.catplot(x='sex', y='survived', kind='bar', data=titanic)
plt.title('Survival rate by gender')
# Out:
# Text(0.5, 1.0, 'Survival rate by gender')

# %%
sns.catplot(x='sex', y='survived', kind='bar',hue = 'sex' , data=titanic)
plt.title('Survival rate by gender');
# El histograma como en el ejemplo

# %% [markdown]
# 34. Using [`kdeplot`]("https://seaborn.pydata.org/generated/seaborn.kdeplot.html") from `seaborn` represent those who not survived distributed by age.<>
#
# Hint: First you should "filter" the `titanic` dataset where the column "survived" is 0, indexing the column `"age"` only.
#
# Arguments you should pass to the function:
#
#     - color = "red"
#     - label = "Not Survived"
#     - shade = True
#
# You should get something like this:

# %% [markdown]
# ![kdeplot](./img/kdeplotsur.png)

# %%
# Filtro de los que no sobrevivieron por edad
not_survived = titanic[titanic['survived'] == 0]['age']
not_survived
# Hay que quitar los valores nulos, y lo hago directamente en el plot
# Out:
# 2        2.0
# 3       30.0
# 4       25.0
# 7       39.0
# 9       71.0
#         ...
# 1304    14.5
# 1305     NaN
# 1306    26.5
# 1307    27.0
# 1308    29.0
# Name: age, Length: 809, dtype: float64

# %%
from matplotlib.lines import Line2D

line = Line2D([0], [0], color='red')

# %%
sns.kdeplot(not_survived.dropna(), color='red', label='Not Survived', fill=True)
plt.title('Age distribution (Not Survived)')
plt.legend(handles=[line], labels=['Not Survived']);

# No se porque la leyenda no me sale igual que en el ejemplo. He intentado de todo y nada jaja.

# %%
# Ver la correlación entre las variables numéricas con corr()
beers[['abv', 'ibu', 'ounces']].corr()
# Out:
#              abv       ibu    ounces
# abv     1.000000  0.670621  0.172529
# ibu     0.670621  1.000000  0.054691
# ounces  0.172529  0.054691  1.000000
