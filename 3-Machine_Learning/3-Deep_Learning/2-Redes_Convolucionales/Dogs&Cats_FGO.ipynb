# %% [markdown]
# ## Redes Convolucionales
# #### Ejemplo clasificación de perros y gatos para CAPTCHA
#
# Este notebook utiliza datos de la [competición de Kaggle Dogs vs. Cats](https://www.kaggle.com/c/dogs-vs-cats/overview). En esta competicion se utiliza Asirra (Animal Species Image Recognition for Restricting Access), CAPTCHA que sirve para diferenciar entre una persona o una máquina accediendo a una página web. Este tipo de "pruebas" se utilizan para evitar emails de spam, y ataques por fuerza bruta contra servidores.
#
# En este notebook vamos a probar que hay técnicas de clasificado automáticas de imágenes mediante redes neuronales, que con las que se intenta saltar CAPTCHA

# %%
# %pip install scikit-image opencv-python # numpy pandas scikit-learn matplotlib keras seaborn tensorflow

# %% [markdown]
# # Import Library

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import random
import os

# %% [markdown]
# # Define Constants
# Tendremos una serie de constantes como las dimensiones de las imágenes, que serán fijas a lo largo de todo el notebook

# %%
IMAGE_WIDTH=32 # tambien lo he cambiado a 48
IMAGE_HEIGHT=32 # tambien lo he cambiado a 48
IMAGE_CHANNELS=3
IMAGE_SIZE=(IMAGE_WIDTH, IMAGE_HEIGHT, IMAGE_CHANNELS)
BATCH_SIZE = 32
EPOCHS = 30

# %% [markdown]
# # Prepare Training Data
# 1. Descárgate el dataset desde [aquí](https://drive.google.com/drive/folders/1WUIVV96pTy1SpL-qMenh3UtgDAEY9hNh?usp=sharing)
# 2. Descomprime el dataset y guardalo en la ruta que quieras del ordenador.
# 3. En este punto vamos guardar en una lista las etiquetas de cada foto.

# %%
os.getcwd()
# Out:
# '/Users/fgoiri/Documents/Documentos_Fatima/Bootcamp/2026-02-BILBAO-FT-Data-Science/3-Machine_Learning/3-Deep_Learning/2-Redes_Convolucionales'

# %%
ROOT_PATH = "/Users/fgoiri/Documents/Documentos_Fatima/dogs_cats/"

TRAIN_PATH = ROOT_PATH+ "train/"
TEST_PATH = ROOT_PATH + "test/"

# %%
##### CODE #####

# Listar todos los archivos de la carpeta de train (TRAIN_PATH)
filenames = os.listdir(TRAIN_PATH)

# Lista vacia
categories = []

# Iterar
for filename in filenames:
    # Saco el nombre
    category = filename.split('.')[0]
    
    # If else
    # Guardo en lista
    if category == 'dog':
        categories.append(1)
    else:
        categories.append(0)
    
    
df = pd.DataFrame({
    'filename': filenames,
    'category': categories
})

# %%
df
# Out:
#            filename  category
# 0      cat.2718.jpg         0
# 1      cat.3406.jpg         0
# 2      cat.1211.jpg         0
# 3     dog.11102.jpg         1
# 4     dog.11664.jpg         1
# ...             ...       ...
# 6571  dog.10563.jpg         1
# 6572   cat.1208.jpg         0
# 6573  dog.10205.jpg         1
# 6574  dog.12412.jpg         1
# 6575   cat.2701.jpg         0
#
# [6576 rows x 2 columns]

# %% [markdown]
# ### See Total In count

# %%
df['category'].value_counts().plot.bar();

# %% [markdown]
# # See sample image

# %%
from skimage.io import imread
import cv2

sample = random.choice(filenames)
image = imread(TRAIN_PATH + sample)

print(image.shape)
print(np.max(image))
plt.imshow(image);
# Out:
# (299, 400, 3)
# 255

# %% [markdown]
# Una imagen no es mas que un array de HxWxC píxeles, siendo H(Height) y W(Width) las dimensiones de resolución de la imagen, y C el número de canales. Habrá tres valores por píxel.

# %%
image
# Out:
# array([[[67, 67, 75],
#         [66, 66, 74],
#         [62, 62, 70],
#         ...,
#         [54, 55, 60],
#         [38, 39, 44],
#         [32, 33, 38]],
#
#        [[67, 67, 75],
#         [66, 66, 74],
#         [62, 62, 70],
#         ...,
#         [54, 55, 60],
#         [39, 40, 45],
#         [32, 33, 38]],
#
#        [[67, 67, 75],
#         [66, 66, 74],
#         [63, 63, 71],
#         ...,
#         [53, 54, 59],
#         [39, 40, 45],
#         [34, 35, 40]],
#
#        ...,
#
#        [[33, 23, 21],
#         [35, 25, 23],
#         [34, 26, 23],
#         ...,
#         [47, 38, 33],
#         [48, 39, 34],
#         [49, 40, 35]],
#
#        [[36, 26, 24],
#         [37, 27, 25],
#         [35, 27, 24],
#         ...,
#         [49, 40, 35],
#         [51, 42, 37],
#         [51, 42, 37]],
#
#        [[40, 30, 28],
#         [39, 29, 27],
#         [35, 27, 24],
#         ...,
#         [52, 43, 38],
#         [53, 44, 39],
#         [54, 45, 40]]], shape=(299, 400, 3), dtype=uint8)

# %% [markdown]
# # Resize image
# Cargar todas las imágenes a la vez es un problema ya que son un total de 25000 (unos 500MB la carpeta de train). Este proceso require mucha memoria, por lo que tendremos que aplicarle un resize a cada imagen para bajarlas de resolución. Esto también nos sirve para solventar el problema de tener imágenes con distintas resoluciones.

# %%
plt.figure(figsize=(12, 12))

sample = random.choice(filenames)
image = imread(TRAIN_PATH + sample)
imagesmall = cv2.resize(image, (IMAGE_WIDTH, IMAGE_HEIGHT))

print("Tamaño imagen original:", image.shape)
print("Tamaño imagen reshape:", imagesmall.shape)

# Original image
plt.subplot(1, 2, 1)
plt.imshow(image)

# Resized image
plt.subplot(1, 2, 2)
plt.imshow(imagesmall);
# Out:
# Tamaño imagen original: (374, 500, 3)
# Tamaño imagen reshape: (48, 48, 3)

# %% [markdown]
# # Color
# Podríamos cargar las imágenes como blanco y negro, de esta forma se reduciría el espacio de features considerablemente al contar con un único canal

# %%
sample = random.choice(filenames)

image = cv2.imread(filename = TRAIN_PATH + sample, flags = cv2.IMREAD_GRAYSCALE)

print("Tamaño imagen original:", image.shape)
plt.imshow(image, cmap='gray');
# Out:
# Tamaño imagen original: (280, 188)

# %% [markdown]
# # Load data
# Llega el momento de cargar los datos. Ya no estan sencillo como cuando teníamos datasets en CSVs puesto que ahora hay que cargar miles de archivos en memoria en este notebook. Para ello necesitaremos un programa iterativo que vaya recorriendo los archivos de la carpeta, cargarlos como array de numpy y almacenarlos en un objeto.

# %%
def read_data(path, im_size):
    X = []
    Y = []

    ##### CODE #####
    # Iterar sobre todo lo que haya en path
    for file in os.listdir(path):
        
        # Leer la imagen a color y aplicarle el resize
        image = imread(path + file)
        smallimage = cv2.resize(image, (im_size, im_size))
        
        # Guardo en X
        X.append(smallimage)
        
        category = file.split('.')[0]
        # Miro si es perro y gato para guardar en Y
        if category == 'dog':
            Y.append(1)
        else:
            Y.append(0)
        

    return np.array(X), np.array(Y)

# %%
X_train, y_train = read_data(TRAIN_PATH, IMAGE_WIDTH)
X_test, y_test = read_data(TEST_PATH, IMAGE_WIDTH)

print(X_train.shape)
print(X_test.shape)
# Out:
# (6576, 48, 48, 3)
# (3456, 48, 48, 3)

# %%
os.listdir(TRAIN_PATH)[1]
# Out:
# 'cat.3406.jpg'

# %%
print(X_train[1].shape)
plt.imshow(X_train[1]);
# Out:
# (48, 48, 3)

# %%
X_train[0]
# Out:
# array([[[ 33,  23,  14],
#         [ 31,  21,  12],
#         [ 33,  26,  16],
#         ...,
#         [104,  63,  39],
#         [108,  66,  42],
#         [104,  74,  46]],
#
#        [[ 36,  26,  17],
#         [ 36,  26,  17],
#         [ 37,  29,  20],
#         ...,
#         [103,  73,  45],
#         [106,  71,  45],
#         [106,  82,  52]],
#
#        [[ 37,  27,  18],
#         [ 37,  27,  18],
#         [ 39,  29,  20],
#         ...,
#         [102,  68,  41],
#         [108,  73,  50],
#         [102,  78,  52]],
#
#        ...,
#
#        [[ 80,  64,  49],
#         [ 75,  59,  44],
#         [ 68,  52,  37],
#         ...,
#         [  0,   1,   0],
#         [ 28,  19,  11],
#         [ 57,  42,  23]],
#
#        [[ 65,  55,  40],
#         [ 58,  47,  33],
#         [ 60,  47,  36],
#         ...,
#         [ 34,  26,  15],
#         [ 38,  29,  14],
#         [ 58,  39,  27]],
#
#        [[ 81,  65,  52],
#         [ 71,  55,  43],
#         [ 76,  59,  43],
#         ...,
#         [ 37,  23,   9],
#         [ 55,  39,  26],
#         [ 48,  39,  24]]], shape=(48, 48, 3), dtype=uint8)

# %% [markdown]
# # Normalized data
# Normalizar los datos hará que entrene mucho mejor la red, al estar todos los pixeles en la misma escala.

# %%
print("Min:", np.min(X_train))
print("Max:", np.max(X_train))
# Out:
# Min: 0
# Max: 255

# %%
X_train = X_train / 255.0
X_test = X_test / 255.0

print("Min:", np.min(X_train))
print("Max:", np.max(X_train))
# Out:
# Min: 0.0
# Max: 1.0

# %% [markdown]
# # Shuffle data
# Como hemos cargado los datos de manera ordenada (primero gatos y luego perros), tendremos que desordenarlos para asegurarnos de que no haya ningún sesgo en el entrenamiento ni en la selección de datos de validación.

# %%
from sklearn.utils import shuffle
X_train, y_train = shuffle(X_train, y_train, random_state=42)

# %%
X_train
# Out:
# array([[[[0.21568627, 0.30980392, 0.41176471],
#          [0.22745098, 0.32156863, 0.41176471],
#          [0.25490196, 0.35294118, 0.43921569],
#          ...,
#          [0.49019608, 0.30980392, 0.17647059],
#          [0.45490196, 0.28235294, 0.16862745],
#          [0.42745098, 0.25098039, 0.16862745]],
#
#         [[0.25098039, 0.35294118, 0.42745098],
#          [0.24705882, 0.34509804, 0.42352941],
#          [0.25490196, 0.35294118, 0.43921569],
#          ...,
#          [0.49411765, 0.31372549, 0.18039216],
#          [0.46666667, 0.29411765, 0.18039216],
#          [0.43137255, 0.25882353, 0.17647059]],
#
#         [[0.21176471, 0.31764706, 0.38431373],
#          [0.25490196, 0.36078431, 0.42745098],
#          [0.27058824, 0.37647059, 0.44313725],
#          ...,
#          [0.50980392, 0.31372549, 0.17647059],
#          [0.48235294, 0.29019608, 0.16470588],
#          [0.43137255, 0.27058824, 0.16078431]],
#
#         ...,
#
#         [[0.47058824, 0.37647059, 0.32941176],
#          [0.46666667, 0.37647059, 0.32156863],
#          [0.45882353, 0.36862745, 0.30588235],
#          ...,
#          [0.63529412, 0.35294118, 0.1254902 ],
#          [0.58823529, 0.31764706, 0.09411765],
#          [0.54901961, 0.29803922, 0.11764706]],
#
#         [[0.45098039, 0.35686275, 0.30980392],
#          [0.43529412, 0.34509804, 0.29019608],
#          [0.45490196, 0.36470588, 0.30196078],
#          ...,
#          [0.63137255, 0.34901961, 0.12156863],
#          [0.59215686, 0.31764706, 0.11372549],
#          [0.54509804, 0.29019608, 0.1254902 ]],
#
#         [[0.42745098, 0.3372549 , 0.27843137],
#          [0.45490196, 0.34117647, 0.28627451],
#          [0.44313725, 0.3372549 , 0.2627451 ],
#          ...,
#          [0.61960784, 0.34117647, 0.12941176],
#          [0.57647059, 0.30980392, 0.11764706],
#          [0.53333333, 0.29019608, 0.11372549]]],
#
#
#        [[[0.09411765, 0.21176471, 0.23529412],
#          [0.1254902 , 0.21176471, 0.24313725],
#          [0.11372549, 0.18431373, 0.19215686],
#          ...,
#          [0.08627451, 0.17254902, 0.19215686],
#          [0.24705882, 0.18431373, 0.1254902 ],
#          [0.21960784, 0.19607843, 0.14901961]],
#
#         [[0.09411765, 0.20392157, 0.24705882],
#          [0.08627451, 0.20392157, 0.24313725],
#          [0.09803922, 0.20784314, 0.26666667],
#          ...,
#          [0.07843137, 0.14509804, 0.17254902],
#          [0.24705882, 0.20784314, 0.16862745],
#          [0.19607843, 0.16862745, 0.1372549 ]],
#
#         [[0.10196078, 0.20784314, 0.26666667],
#          [0.06666667, 0.20784314, 0.25490196],
#          [0.10196078, 0.19215686, 0.24705882],
#          ...,
#          [0.09803922, 0.14117647, 0.17647059],
#          [0.18039216, 0.16078431, 0.1372549 ],
#          [0.21176471, 0.18039216, 0.16862745]],
#
#         ...,
#
#         [[0.15686275, 0.15686275, 0.18823529],
#          [0.15294118, 0.14117647, 0.18039216],
#          [0.18039216, 0.16078431, 0.18431373],
#          ...,
#          [0.61568627, 0.48627451, 0.55686275],
#          [0.11764706, 0.1254902 , 0.16862745],
#          [0.60784314, 0.61568627, 0.58823529]],
#
#         [[0.17254902, 0.16862745, 0.18039216],
#          [0.18431373, 0.15686275, 0.17647059],
#          [0.19215686, 0.16862745, 0.16862745],
#          ...,
#          [0.59215686, 0.45098039, 0.45490196],
#          [0.10196078, 0.12941176, 0.17254902],
#          [0.14509804, 0.14901961, 0.15294118]],
#
#         [[0.20392157, 0.20392157, 0.21176471],
#          [0.21176471, 0.19215686, 0.20784314],
#          [0.21176471, 0.20392157, 0.20784314],
#          ...,
#          [0.54117647, 0.42745098, 0.40392157],
#          [0.16078431, 0.14901961, 0.19215686],
#          [0.14901961, 0.16078431, 0.18823529]]],
#
#
#        [[[0.61568627, 0.56078431, 0.38823529],
#          [0.61568627, 0.56078431, 0.37647059],
#          [0.60392157, 0.54901961, 0.35686275],
#          ...,
#          [0.3254902 , 0.23529412, 0.04705882],
#          [0.4627451 , 0.32156863, 0.11764706],
#          [0.52156863, 0.36470588, 0.13333333]],
#
#         [[0.63137255, 0.57647059, 0.4       ],
#          [0.60392157, 0.54901961, 0.36470588],
#          [0.6       , 0.54509804, 0.35294118],
#          ...,
#          [0.48627451, 0.38823529, 0.23137255],
#          [0.48235294, 0.35294118, 0.15686275],
#          [0.56470588, 0.41568627, 0.18431373]],
#
#         [[0.63137255, 0.57647059, 0.4       ],
#          [0.61568627, 0.56078431, 0.37647059],
#          [0.6       , 0.54509804, 0.35294118],
#          ...,
#          [0.40392157, 0.30980392, 0.16470588],
#          [0.42352941, 0.31372549, 0.12941176],
#          [0.46666667, 0.3254902 , 0.11372549]],
#
#         ...,
#
#         [[0.63137255, 0.57647059, 0.43137255],
#          [0.7254902 , 0.67058824, 0.5254902 ],
#          [0.78039216, 0.7254902 , 0.58039216],
#          ...,
#          [0.60784314, 0.54509804, 0.41176471],
#          [0.60392157, 0.54117647, 0.40784314],
#          [0.56470588, 0.50588235, 0.37254902]],
#
#         [[0.62352941, 0.56862745, 0.43137255],
#          [0.6627451 , 0.60784314, 0.47058824],
#          [0.8       , 0.74509804, 0.60784314],
#          ...,
#          [0.56078431, 0.49803922, 0.36470588],
#          [0.59215686, 0.52941176, 0.39607843],
#          [0.58039216, 0.52156863, 0.38823529]],
#
#         [[0.56078431, 0.50196078, 0.37254902],
#          [0.75686275, 0.69803922, 0.56862745],
#          [0.72941176, 0.67058824, 0.54117647],
#          ...,
#          [0.61568627, 0.55294118, 0.41960784],
#          [0.58039216, 0.51764706, 0.38431373],
#          [0.61176471, 0.55294118, 0.41568627]]],
#
#
#        ...,
#
#
#        [[[0.62745098, 0.58823529, 0.58823529],
#          [0.76862745, 0.76078431, 0.8       ],
#          [0.64313725, 0.61960784, 0.59215686],
#          ...,
#          [0.71764706, 0.67058824, 0.70980392],
#          [0.92156863, 0.91372549, 0.9372549 ],
#          [0.93333333, 0.90196078, 0.93333333]],
#
#         [[0.59215686, 0.55294118, 0.55294118],
#          [0.81568627, 0.80784314, 0.84705882],
#          [0.69019608, 0.66666667, 0.63921569],
#          ...,
#          [0.73333333, 0.71372549, 0.74117647],
#          [0.90588235, 0.92156863, 0.94117647],
#          [0.91764706, 0.90980392, 0.9372549 ]],
#
#         [[0.55686275, 0.51764706, 0.50980392],
#          [0.85882353, 0.82745098, 0.8627451 ],
#          [0.65882353, 0.63137255, 0.63529412],
#          ...,
#          [0.91372549, 0.88627451, 0.91764706],
#          [0.9372549 , 0.91372549, 0.94117647],
#          [0.94117647, 0.91372549, 0.94509804]],
#
#         ...,
#
#         [[0.78823529, 0.75686275, 0.74901961],
#          [0.8       , 0.76862745, 0.76078431],
#          [0.86666667, 0.83529412, 0.82745098],
#          ...,
#          [0.83921569, 0.8       , 0.76078431],
#          [0.8627451 , 0.82745098, 0.78823529],
#          [0.85490196, 0.81568627, 0.77647059]],
#
#         [[0.87843137, 0.83921569, 0.83529412],
#          [0.88627451, 0.84705882, 0.84313725],
#          [0.86666667, 0.83137255, 0.82745098],
#          ...,
#          [0.81960784, 0.78039216, 0.74117647],
#          [0.81960784, 0.78039216, 0.74117647],
#          [0.80392157, 0.76470588, 0.7254902 ]],
#
#         [[0.86666667, 0.82745098, 0.82352941],
#          [0.85098039, 0.81176471, 0.80784314],
#          [0.85098039, 0.81568627, 0.80784314],
#          ...,
#          [0.90588235, 0.86666667, 0.82745098],
#          [0.90980392, 0.87058824, 0.83137255],
#          [0.8627451 , 0.82352941, 0.78431373]]],
#
#
#        [[[0.57254902, 0.54901961, 0.56470588],
#          [0.56078431, 0.53333333, 0.56078431],
#          [0.58039216, 0.54117647, 0.57254902],
#          ...,
#          [0.74509804, 0.70196078, 0.68627451],
#          [0.61176471, 0.50588235, 0.42352941],
#          [0.62745098, 0.52156863, 0.43921569]],
#
#         [[0.56470588, 0.5372549 , 0.56470588],
#          [0.58039216, 0.56078431, 0.54901961],
#          [0.59215686, 0.58039216, 0.54901961],
#          ...,
#          [0.59215686, 0.5254902 , 0.46666667],
#          [0.6       , 0.45490196, 0.38431373],
#          [0.61568627, 0.47058824, 0.4       ]],
#
#         [[0.57647059, 0.5372549 , 0.58039216],
#          [0.60392157, 0.59215686, 0.55294118],
#          [0.70980392, 0.71764706, 0.67058824],
#          ...,
#          [0.69019608, 0.62352941, 0.56862745],
#          [0.76078431, 0.66666667, 0.6       ],
#          [0.61176471, 0.55294118, 0.46666667]],
#
#         ...,
#
#         [[0.46666667, 0.39215686, 0.36470588],
#          [0.45098039, 0.38039216, 0.35294118],
#          [0.44705882, 0.37254902, 0.34509804],
#          ...,
#          [0.37254902, 0.26666667, 0.21176471],
#          [0.35294118, 0.26666667, 0.20392157],
#          [0.35294118, 0.2627451 , 0.2       ]],
#
#         [[0.43921569, 0.36470588, 0.3372549 ],
#          [0.46666667, 0.39215686, 0.36470588],
#          [0.44705882, 0.37254902, 0.34509804],
#          ...,
#          [0.33333333, 0.25098039, 0.18431373],
#          [0.35686275, 0.26666667, 0.20392157],
#          [0.36470588, 0.2745098 , 0.21176471]],
#
#         [[0.45490196, 0.4       , 0.36470588],
#          [0.43529412, 0.36470588, 0.31764706],
#          [0.44705882, 0.36078431, 0.30588235],
#          ...,
#          [0.49411765, 0.44313725, 0.36862745],
#          [0.41960784, 0.35294118, 0.28235294],
#          [0.36470588, 0.29803922, 0.21568627]]],
#
#
#        [[[0.4627451 , 0.46666667, 0.39607843],
#          [0.4627451 , 0.46666667, 0.39607843],
#          [0.46666667, 0.47058824, 0.41568627],
#          ...,
#          [0.50980392, 0.51764706, 0.4627451 ],
#          [0.49019608, 0.50588235, 0.45098039],
#          [0.4627451 , 0.47843137, 0.42352941]],
#
#         [[0.46666667, 0.47058824, 0.4       ],
#          [0.46666667, 0.47058824, 0.4       ],
#          [0.47843137, 0.48235294, 0.42745098],
#          ...,
#          [0.52156863, 0.53333333, 0.4745098 ],
#          [0.50196078, 0.51764706, 0.4627451 ],
#          [0.4745098 , 0.49019608, 0.43921569]],
#
#         [[0.47843137, 0.46666667, 0.4       ],
#          [0.47843137, 0.46666667, 0.4       ],
#          [0.49019608, 0.47843137, 0.41176471],
#          ...,
#          [0.5254902 , 0.52941176, 0.4745098 ],
#          [0.51372549, 0.52156863, 0.46666667],
#          [0.49019608, 0.49803922, 0.44313725]],
#
#         ...,
#
#         [[0.47058824, 0.41960784, 0.35686275],
#          [0.45882353, 0.40784314, 0.34509804],
#          [0.49411765, 0.44313725, 0.38039216],
#          ...,
#          [0.46666667, 0.41568627, 0.35294118],
#          [0.45882353, 0.40784314, 0.34509804],
#          [0.44313725, 0.39607843, 0.33333333]],
#
#         [[0.52941176, 0.47843137, 0.41568627],
#          [0.45490196, 0.40784314, 0.34509804],
#          [0.48627451, 0.43529412, 0.37254902],
#          ...,
#          [0.45882353, 0.40784314, 0.34509804],
#          [0.47843137, 0.42745098, 0.36470588],
#          [0.4627451 , 0.41176471, 0.34901961]],
#
#         [[0.55294118, 0.5254902 , 0.45490196],
#          [0.50196078, 0.45098039, 0.38823529],
#          [0.43529412, 0.38431373, 0.30980392],
#          ...,
#          [0.49803922, 0.4627451 , 0.40392157],
#          [0.43921569, 0.40392157, 0.34509804],
#          [0.43137255, 0.39607843, 0.3372549 ]]]], shape=(6576, 48, 48, 3))

# %% [markdown]
# # Save data
# Podemos guardar los arrays de numpy en un archivo `.npz`, de tal manera que luego sea más rápido importarlo

# %%
np.savez(ROOT_PATH + '/data.npz',
        X_train = X_train,
        y_train = y_train,
        X_test = X_test,
        y_test = y_test)

# %%
ROOT_PATH
# Out:
# '/Users/fgoiri/Documents/Documentos_Fatima/dogs_cats/'

# %% [markdown]
# Para cargar

# %%
data = np.load(ROOT_PATH + '/data.npz')
X_train = data['X_train']
X_test = data['X_test']
y_train = data['y_train']
y_test = data['y_test']

# %% [markdown]
# # Build Model
#
# <img src="https://i.imgur.com/ebkMGGu.jpg" width="100%"/>

# %% [markdown]
# * **Conv Layer**: extraerá diferentes features de las imagenes
# * **Pooling Layer**: Reduce las dimensiones de las imágenes tras una capa convolucional
# * **Fully Connected Layer**: Tras las capas convolucionales, aplanamos las features y las introducimos como entrada de una red neuronal normal.
# * **Output Layer**: Las predicciones de la red
#
# Para el loss y la metrica, se puede usar un binary_crossentropy, al ser un target binario.

# %%
IMAGE_SIZE
# Out:
# (48, 48, 3)

# %%
from tensorflow import keras

layers = [
    keras.layers.Conv2D(64, (3,3), activation='relu', input_shape=IMAGE_SIZE),
    keras.layers.MaxPooling2D(pool_size=(2,2)),
    
    keras.layers.Conv2D(128, (3,3), activation='relu'),
    keras.layers.MaxPooling2D(pool_size=(2,2)),
    
    keras.layers.Flatten(),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dense(64, activation='relu'),
    keras.layers.Dense(1, activation='sigmoid')
]

model = keras.Sequential(layers)

model.compile(optimizer = 'adam',
             loss = 'binary_crossentropy',
             metrics = ['accuracy'])
# Out:
# /Users/fgoiri/miniconda3/envs/bootcamp2/lib/python3.11/site-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_2 (Conv2D)               │ (None, 46, 46, 64)     │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 23, 23, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 21, 21, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 10, 10, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 12800)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 128)            │     1,638,528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,722,497 (6.57 MB)
#  Trainable params: 1,722,497 (6.57 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# # Callbacks
# #### Early Stopping

# %%
from keras.callbacks import EarlyStopping
earlystop = EarlyStopping(patience=10)

# %%
from keras.callbacks import ModelCheckpoint
mcheckpoint = ModelCheckpoint("callback_model.keras") # que vaya guardando la red según se entrena por si el ordenador se china

# %% [markdown]
# # Fit the model

# %%
history = model.fit(X_train,
         y_train,
         epochs = EPOCHS,
         batch_size = BATCH_SIZE,
         callbacks = [earlystop, mcheckpoint],
         validation_split = 0.2)
# Out:
# Epoch 1/30
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.6249 - loss: 0.6483 - val_accuracy: 0.7029 - val_loss: 0.5751
# Epoch 2/30
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - accuracy: 0.7179 - loss: 0.5586 - val_accuracy: 0.7257 - val_loss: 0.5429
# Epoch 3/30
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - accuracy: 0.7582 - loss: 0.5015 - val_accuracy: 0.7530 - val_loss: 0.5034
# Epoch 4/30
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - accuracy: 0.7970 - loss: 0.4395 - val_accuracy: 0.7546 - val_loss: 0.5233
# Epoch 5/30
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - accuracy: 0.8281 - loss: 0.3845 - val_accuracy: 0.7682 - val_loss: 0.5060
# Epoch 6/30
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - accuracy: 0.8683 - loss: 0.2978 - val_accuracy: 0.7629 - val_loss: 0.5607
# Epoch 7/30
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - accuracy: 0.9053 - loss: 0.2324 - val_accuracy: 0.7105 - val_loss: 0.7009
# Epoch 8/30
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - accuracy: 0.9376 - loss: 0.1558 - val_accuracy: 0.7340 - val_loss: 0.8081
# Epoch 9/30
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - accuracy: 0.9570 - loss: 0.1071 - val_accuracy: 0.7508 - val_loss: 0.9021
# Epoch 10/30
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - accuracy: 0.9709 - loss: 0.0734 - val_accuracy: 0.7424 - val_loss: 1.0293
# Epoch 11/30
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - accuracy: 0.9791 - loss: 0.0631 - val_accuracy: 0.7090 - val_loss: 1.1049
# Epoch 12/30
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - accuracy: 0.9880 - loss: 0.0366 - val_accuracy: 0.7363 - val_loss: 1.2838
# Epoch 13/30
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - accuracy: 0.9848 - loss: 0.0408 - val_accuracy: 0.7386 - val_loss: 1.1741

# %%
results = model.evaluate(X_test, y_test)
print("test loss, test acc:", results)
# Out:
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7361 - loss: 1.2621
# test loss, test acc: [1.2620866298675537, 0.7361111044883728]

# %%
pd.DataFrame(history.history).plot()
# Out:
# <Axes: >

# %%
pd.DataFrame(history.history).head(10)
# Out:
#    accuracy      loss  val_accuracy  val_loss
# 0  0.624905  0.648295      0.702888  0.575059
# 1  0.717871  0.558560      0.725684  0.542895
# 2  0.758175  0.501489      0.753040  0.503391
# 3  0.796958  0.439491      0.754559  0.523272
# 4  0.828137  0.384514      0.768237  0.506004
# 5  0.868251  0.297811      0.762918  0.560685
# 6  0.905323  0.232399      0.710486  0.700917
# 7  0.937643  0.155802      0.734043  0.808059
# 8  0.957034  0.107092      0.750760  0.902082
# 9  0.970913  0.073398      0.742401  1.029290

# %% [markdown]
# # Evaluate
# Probemos los datos en el conjunto de test.

# %%
results = model.evaluate(X_test, y_test)
results
# Out:
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7361 - loss: 1.2621
# [1.2620866298675537, 0.7361111044883728]

# %%
model.predict(X_test).round(0)
# Out:
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step
# array([[0.],
#        [1.],
#        [1.],
#        ...,
#        [0.],
#        [0.],
#        [1.]], shape=(3456, 1), dtype=float32)

# %%
from sklearn.metrics import confusion_matrix

confusion_matrix(y_test, model.predict(X_test).round(0))
# Out:
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step
# array([[1269,  379],
#        [ 533, 1275]])

# %%
plt.imshow(X_test[-3]);

# %%
X_test[-4:-3]
# Out:
# array([[[[0.40784314, 0.41960784, 0.45490196],
#          [0.43529412, 0.44705882, 0.48235294],
#          [0.43137255, 0.44313725, 0.47843137],
#          ...,
#          [0.25098039, 0.26666667, 0.27843137],
#          [0.38431373, 0.41176471, 0.45098039],
#          [0.43529412, 0.4627451 , 0.50196078]],
#
#         [[0.41176471, 0.42352941, 0.45882353],
#          [0.44705882, 0.45882353, 0.49411765],
#          [0.45490196, 0.46666667, 0.50196078],
#          ...,
#          [0.29411765, 0.30588235, 0.32156863],
#          [0.4       , 0.42352941, 0.48235294],
#          [0.4627451 , 0.48627451, 0.54117647]],
#
#         [[0.41176471, 0.42352941, 0.45882353],
#          [0.45490196, 0.46666667, 0.50196078],
#          [0.45490196, 0.46666667, 0.50196078],
#          ...,
#          [0.36078431, 0.37254902, 0.39215686],
#          [0.45490196, 0.4745098 , 0.53333333],
#          [0.49803922, 0.52156863, 0.57647059]],
#
#         ...,
#
#         [[0.46666667, 0.46666667, 0.47058824],
#          [0.47058824, 0.47058824, 0.4627451 ],
#          [0.84705882, 0.83137255, 0.81960784],
#          ...,
#          [0.74901961, 0.74117647, 0.74509804],
#          [0.84705882, 0.82352941, 0.83137255],
#          [0.8       , 0.77647059, 0.78431373]],
#
#         [[0.55686275, 0.55686275, 0.56470588],
#          [0.59215686, 0.58431373, 0.58823529],
#          [0.49019608, 0.4745098 , 0.4627451 ],
#          ...,
#          [0.49803922, 0.48627451, 0.49411765],
#          [0.61176471, 0.59607843, 0.6       ],
#          [0.77254902, 0.75686275, 0.76078431]],
#
#         [[0.61960784, 0.61176471, 0.62745098],
#          [0.87843137, 0.86666667, 0.87058824],
#          [0.74117647, 0.70588235, 0.71372549],
#          ...,
#          [0.54509804, 0.5372549 , 0.54117647],
#          [0.50588235, 0.50196078, 0.48235294],
#          [0.84705882, 0.84313725, 0.83137255]]]], shape=(1, 48, 48, 3))

# %%
predictions = model.predict(X_test[-4:-3])
predictions
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# array([[0.00031252]], dtype=float32)

# %% [markdown]
# # Image data generator

# %%
df["category"] = df["category"].replace({0: 'cat', 1: 'dog'})

print("Categorias:", df['category'].unique())
df.head()
# Out:
# Categorias: ['cat' 'dog']
#         filename category
# 0   cat.2718.jpg      cat
# 1   cat.3406.jpg      cat
# 2   cat.1211.jpg      cat
# 3  dog.11102.jpg      dog
# 4  dog.11664.jpg      dog

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img

example_df = df.sample(n=1).reset_index(drop=True)
example_df

train_datagen = ImageDataGenerator(
    rescale = 1./255,
    rotation_range = 15,
    shear_range = 0.1,
    zoom_range=0.2,
    horizontal_flip=True,
    width_shift_range = 0.1,
    height_shift_range = 0.1
)

example_generator = train_datagen.flow_from_dataframe(
    example_df,
    TRAIN_PATH,
    x_col = 'filename',
    y_col = 'category',
    target_size = (128, 128)
)
# Out:
# Found 1 validated image filenames belonging to 1 classes.

# %%
example_df
# Out:
#       filename category
# 0  cat.676.jpg      cat

# %%
plt.figure(figsize=(12, 12))

for i in range(0, 15):
    plt.subplot(5, 3, i+1)
    for X_batch, Y_batch in example_generator:
        image = X_batch[0]
        plt.imshow(image)
        break
plt.tight_layout()
plt.show()

# %% [markdown]
# # Training Generator

# %%
train_df, validate_df = train_test_split(df,
                                         test_size=0.20,
                                         random_state=42)

train_df = train_df.reset_index(drop=True)
validate_df = validate_df.reset_index(drop=True)

# %%
total_train = train_df.shape[0]
total_validate = validate_df.shape[0]

print("Shape train", total_train)
print("Shape validation", total_validate)
validate_df.head()
# Out:
# Shape train 5260
# Shape validation 1316
#         filename category
# 0    cat.818.jpg      cat
# 1   cat.3133.jpg      cat
# 2   cat.3204.jpg      cat
# 3  dog.10405.jpg      dog
# 4   cat.2145.jpg      cat

# %%
train_df.head()
# Out:
#         filename category
# 0   cat.1088.jpg      cat
# 1   cat.1169.jpg      cat
# 2     cat.91.jpg      cat
# 3  dog.10489.jpg      dog
# 4    cat.485.jpg      cat

# %%
train_datagen = ImageDataGenerator(
    rescale = 1./255,
    rotation_range = 15,
    shear_range = 0.1,
    zoom_range=0.2,
    horizontal_flip=True,
    width_shift_range = 0.1,
    height_shift_range = 0.1
)

train_generator = train_datagen.flow_from_dataframe(
    train_df, 
    TRAIN_PATH, 
    x_col='filename',
    y_col='category',
    target_size=(IMAGE_HEIGHT, IMAGE_WIDTH),
    class_mode='binary',
    batch_size=BATCH_SIZE
)
# Out:
# Found 5260 validated image filenames belonging to 2 classes.

# %% [markdown]
# ### Validation Generator

# %%
validation_datagen = ImageDataGenerator(rescale=1./255)
validation_generator = validation_datagen.flow_from_dataframe(
    validate_df, 
    TRAIN_PATH, 
    x_col='filename',
    y_col='category',
    target_size=(IMAGE_HEIGHT, IMAGE_WIDTH),
    class_mode='binary',
    batch_size=BATCH_SIZE
)
# Out:
# Found 1316 validated image filenames belonging to 2 classes.

# %% [markdown]
# # Fit Model

# %%
model = keras.Sequential(layers)

model.compile(optimizer = 'adam',
             loss = 'binary_crossentropy',
             metrics = ['accuracy'])

# %%
history = model.fit(
    train_generator,
    batch_size=BATCH_SIZE,
    epochs=EPOCHS,
    validation_data = validation_generator
)
# Out:
# Epoch 1/30
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 6s 35ms/step - accuracy: 0.7297 - loss: 0.5717 - val_accuracy: 0.8868 - val_loss: 0.2979
# Epoch 2/30
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - accuracy: 0.7624 - loss: 0.4969 - val_accuracy: 0.8488 - val_loss: 0.3507
# Epoch 3/30
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - accuracy: 0.7641 - loss: 0.4866 - val_accuracy: 0.9126 - val_loss: 0.2933
# Epoch 4/30
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - accuracy: 0.7730 - loss: 0.4807 - val_accuracy: 0.9081 - val_loss: 0.2957
# Epoch 5/30
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - accuracy: 0.7715 - loss: 0.4665 - val_accuracy: 0.8868 - val_loss: 0.2869
# Epoch 6/30
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - accuracy: 0.7812 - loss: 0.4613 - val_accuracy: 0.8967 - val_loss: 0.2821
# Epoch 7/30
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - accuracy: 0.7875 - loss: 0.4572 - val_accuracy: 0.8913 - val_loss: 0.2864
# Epoch 8/30
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - accuracy: 0.7966 - loss: 0.4476 - val_accuracy: 0.7903 - val_loss: 0.4052
# Epoch 9/30
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - accuracy: 0.7990 - loss: 0.4344 - val_accuracy: 0.8222 - val_loss: 0.3905
# Epoch 10/30
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - accuracy: 0.7941 - loss: 0.4361 - val_accuracy: 0.8655 - val_loss: 0.3192
# Epoch 11/30
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - accuracy: 0.8046 - loss: 0.4289 - val_accuracy: 0.8685 - val_loss: 0.3052
# Epoch 12/30
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - accuracy: 0.8065 - loss: 0.4225 - val_accuracy: 0.8495 - val_loss: 0.3257
# Epoch 13/30
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - accuracy: 0.8124 - loss: 0.4159 - val_accuracy: 0.8739 - val_loss: 0.2973
# Epoch 14/30
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - accuracy: 0.8141 - loss: 0.4041 - val_accuracy: 0.8769 - val_loss: 0.2898
# Epoch 15/30
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - accuracy: 0.8150 - loss: 0.4113 - val_accuracy: 0.8518 - val_loss: 0.3356
# Epoch 16/30
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - accuracy: 0.8152 - loss: 0.3986 - val_accuracy: 0.8647 - val_loss: 0.3120
# Epoch 17/30
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - accuracy: 0.8184 - loss: 0.3945 - val_accuracy: 0.8214 - val_loss: 0.3776
# Epoch 18/30
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - accuracy: 0.8262 - loss: 0.3868 - val_accuracy: 0.8526 - val_loss: 0.3354
# Epoch 19/30
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - accuracy: 0.8184 - loss: 0.3844 - val_accuracy: 0.8625 - val_loss: 0.3113
# Epoch 20/30
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - accuracy: 0.8232 - loss: 0.3905 - val_accuracy: 0.8632 - val_loss: 0.3340
# Epoch 21/30
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 5s 31ms/step - accuracy: 0.8177 - loss: 0.3843 - val_accuracy: 0.8663 - val_loss: 0.3122
# Epoch 22/30
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8295 - loss: 0.3686 - val_accuracy: 0.8442 - val_loss: 0.3543
# Epoch 23/30
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 5s 31ms/step - accuracy: 0.8314 - loss: 0.3623 - val_accuracy: 0.8655 - val_loss: 0.3011
# Epoch 24/30
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - accuracy: 0.8304 - loss: 0.3700 - val_accuracy: 0.8412 - val_loss: 0.3457
# Epoch 25/30
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8409 - loss: 0.3614 - val_accuracy: 0.8298 - val_loss: 0.3731
# Epoch 26/30
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8496 - loss: 0.3492 - val_accuracy: 0.8093 - val_loss: 0.4016
# Epoch 27/30
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8460 - loss: 0.3479 - val_accuracy: 0.8176 - val_loss: 0.3855
# Epoch 28/30
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8515 - loss: 0.3491 - val_accuracy: 0.7743 - val_loss: 0.4827
# Epoch 29/30
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8384 - loss: 0.3515 - val_accuracy: 0.8731 - val_loss: 0.3046
# Epoch 30/30
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8443 - loss: 0.3442 - val_accuracy: 0.8480 - val_loss: 0.3305

# %%
pd.DataFrame(history.history).plot()
# Out:
# <Axes: >

# %%
##### CODE #####

# Listar todos los archivos de la carpeta de train (TEST_PATH)
filenames = os.listdir(TEST_PATH)

# Lista vacia
categories = []

# Iterar
for filename in filenames:
    # Saco el nombre
    category = filename.split('.')[0]
    
    # If else
    # Guardo en lista
    if category == 'dog':
        categories.append('dog')
    else:
        categories.append('cat')
    
    
test_df = pd.DataFrame({
    'filename': filenames,
    'category': categories
})

# %%
test_df
# Out:
#            filename category
# 0     cat.12020.jpg      cat
# 1      dog.9469.jpg      dog
# 2     cat.11529.jpg      cat
# 3      dog.8777.jpg      dog
# 4      dog.8763.jpg      dog
# ...             ...      ...
# 3451   dog.9470.jpg      dog
# 3452  cat.11530.jpg      cat
# 3453  cat.12039.jpg      cat
# 3454  cat.11256.jpg      cat
# 3455   dog.9316.jpg      dog
#
# [3456 rows x 2 columns]

# %%
test_datagen = ImageDataGenerator(rescale=1./255)
test_generator = test_datagen.flow_from_dataframe(
    test_df, 
    TEST_PATH, 
    x_col='filename',
    y_col='category',
    target_size=(IMAGE_HEIGHT, IMAGE_WIDTH),
    class_mode='binary',
    batch_size=BATCH_SIZE
)
# Out:
# Found 3456 validated image filenames belonging to 2 classes.

# %%
len(test_generator)
# Out:
# 108

# %%
results = model.evaluate(test_generator)
print("test loss, test acc:", results)
# Out:
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.8174 - loss: 0.4168
# test loss, test acc: [0.4168476164340973, 0.8174189925193787]

# %%
results = model.evaluate(X_test, y_test)
print("test loss, test acc:", results)
# Out:
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8145 - loss: 0.4110
# test loss, test acc: [0.41104796528816223, 0.8145254850387573]

# %% [markdown]
# # Virtualize Training

# %%
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12, 6))
ax1.plot(history.history['loss'], color='b', label="Training loss")
ax1.plot(history.history['val_loss'], color='r', label="validation loss")
ax1.set_xticks(np.arange(1, EPOCHS, 1))
ax1.set_yticks(np.arange(0, 1, 0.1))

ax2.plot(history.history['accuracy'], color='g', label="Training accuracy")
ax2.plot(history.history['val_accuracy'], color='orange',label="Validation accuracy")
ax2.set_xticks(np.arange(1, EPOCHS, 1))

plt.legend(loc='best', shadow=True)
plt.tight_layout()
plt.show()
