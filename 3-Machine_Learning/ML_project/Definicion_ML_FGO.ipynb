# %% [markdown]
# # INFORMACIÓN DEL PROYECTO

# %% [markdown]
# ### TÍTULO

# %%
#Escribe el título del proyecto en Markdown
titulo = "Clasificación de tipos de Cáncer mediante expresión génica RNA-Seq"

# %% [markdown]
# ### TEMA

# %%
# Describe brevemente el tema del proyecto en Markdown
tema = '''
Este proyecto pretende realizar una clasificación multiclase supervisada con datos de expresión génica obtenidos mediante RNA-Seq (RNA Sequencing)
RNA-Seq es una técnica de secuenciación de alto rendimiento que cuantifica los niveles de transcripción génica en muestras tumorales.
El dataset, extraído del repositorio UCI Machine Learning Repository, contiene 801 muestras de pacientes y 20.531 features correspondientes 
a niveles de expresión génica normalizados. Las muestras están etiquetadas en 5 clases: BRCA, KIRC, COAD, LUAD y PRAD.
El objetivo es entrenar modelos de clasificación (Random Forest, SVM, KNN, etc.) capaces de predecir el subtipo tumoral a partir del perfil 
transcriptómico, evaluando métricas como accuracy, F1-score y matriz de confusión.
Dado el alto número de features respecto al número de muestras (problema p >> n), 
se aplicarán técnicas de reducción de dimensionalidad como PCA o selección de features para mitigar el riesgo de overfitting
'''

# %% [markdown]
# ### OBJETIVOS

# %% [markdown]
# Define aquí el objetivo del proyecto

# %% [markdown]
# - Construir un modelo de clasificación multiclase usando datos de expresión génica.
# - Evaluar qué algoritmos de ML (Random Forest, SVM, etc.) obtienen mejor precisión

# %% [markdown]
# ## OBTENCIÓN DE LOS DATOS

# %% [markdown]
# ### DATASETS Y FUENTES ALTERNATIVAS DE DATOS

# %% [markdown]
# Incluye aquí una vista del dataset o datasets de los que partirás para poder evaluar tu hipótesis. <br>
# También incluye el origen de estos datos y su fuente.

# %%
# Fuente: UCI Machine Learning Repository
# URL: https://archive.ics.uci.edu/dataset/401/gene+expression+cancer+rna+seq
# 801 muestras, 20.531 features (genes), 5 clases de cáncer

# %%
import pandas as pd
df = pd.read_csv('data/data.csv',index_col=0)
labels = pd.read_csv('data/labels.csv', index_col=0)

# %% [markdown]
# Muestra mediante un head() los principales datasets con los que vas a trabajar

# %%
# Dataset general:
df.head(10)
# Out:
#           gene_0    gene_1    gene_2    gene_3     gene_4  gene_5    gene_6  \
# sample_0     0.0  2.017209  3.265527  5.478487  10.431999     0.0  7.175175
# sample_1     0.0  0.592732  1.588421  7.586157   9.623011     0.0  6.816049
# sample_2     0.0  3.511759  4.327199  6.881787   9.870730     0.0  6.972130
# sample_3     0.0  3.663618  4.507649  6.659068  10.196184     0.0  7.843375
# sample_4     0.0  2.655741  2.821547  6.539454   9.738265     0.0  6.566967
# sample_5     0.0  3.467853  3.581918  6.620243   9.706829     0.0  7.758510
# sample_6     0.0  1.224966  1.691177  6.572007   9.640511     0.0  6.754888
# sample_7     0.0  2.854853  1.750478  7.226720   9.758691     0.0  5.952103
# sample_8     0.0  3.992125  2.772730  6.546692  10.488252     0.0  7.690222
# sample_9     0.0  3.642494  4.423558  6.849511   9.464466     0.0  7.947216
#
#             gene_7  gene_8    gene_9  ...  gene_20521  gene_20522  gene_20523  \
# ...

# %%
# Clases:
labels['Class'].value_counts()
# Out:
# Class
# BRCA    300
# KIRC    146
# LUAD    141
# PRAD    136
# COAD     78
# Name: count, dtype: int64
